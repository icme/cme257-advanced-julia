# %%
# CME 257 Homework 3

# %%
# Julia v0.4.0
# The palette collection shows some of the colors here, and was originally designed for maps.
# More information at https://github.com/timothyrenner/ColorBrewer.jl

# %%
using ColorBrewer

# %%
using Gadfly

# %%
# Pastel1

# %%
pastel1 = palette("Pastel1", 9)
# Out:
# 9-element Array{Any,1}:
#  RGB{U8}(0.984,0.706,0.682)
#  RGB{U8}(0.702,0.804,0.89)
#  RGB{U8}(0.8,0.922,0.773)
#  RGB{U8}(0.871,0.796,0.894)
#  RGB{U8}(0.996,0.851,0.651)
#  RGB{U8}(1.0,1.0,0.8)
#  RGB{U8}(0.898,0.847,0.741)
#  RGB{U8}(0.992,0.855,0.925)
#  RGB{U8}(0.949,0.949,0.949)

# %%
plot([x -> cos(n*x) for n in 1:5], 0, 3, Scale.color_discrete_manual(pastel1[3:7]...))
# Out:
# Plot(...)

# %%
# Pastel2

# %%
pastel2 = palette("Pastel2", 8)
# Out:
# 8-element Array{Any,1}:
#  RGB{U8}(0.702,0.886,0.804)
#  RGB{U8}(0.992,0.804,0.675)
#  RGB{U8}(0.796,0.835,0.91)
#  RGB{U8}(0.957,0.792,0.894)
#  RGB{U8}(0.902,0.961,0.788)
#  RGB{U8}(1.0,0.949,0.682)
#  RGB{U8}(0.945,0.886,0.8)
#  RGB{U8}(0.8,0.8,0.8)

# %%
plot([x -> cos(n*x) for n in 1:5], 0, 3, Scale.color_discrete_manual(pastel2[1:5]...))
# Out:
# Plot(...)

# %%
# Red

# %%
red = palette("Reds", 9)
# Out:
# 9-element Array{Any,1}:
#  RGB{U8}(1.0,0.961,0.941)
#  RGB{U8}(0.996,0.878,0.824)
#  RGB{U8}(0.988,0.733,0.631)
#  RGB{U8}(0.988,0.573,0.447)
#  RGB{U8}(0.984,0.416,0.29)
#  RGB{U8}(0.937,0.231,0.173)
#  RGB{U8}(0.796,0.094,0.114)
#  RGB{U8}(0.647,0.059,0.082)
#  RGB{U8}(0.404,0.0,0.051)

# %%
plot([x -> cos(n*x) for n in 1:5], 0, 2, Scale.color_discrete_manual(red[3:7]...))
# Out:
# Plot(...)

# %%
# Orange

# %%
orange = palette("Oranges", 9)
# Out:
# 9-element Array{Any,1}:
#  RGB{U8}(1.0,0.961,0.922)
#  RGB{U8}(0.996,0.902,0.808)
#  RGB{U8}(0.992,0.816,0.635)
#  RGB{U8}(0.992,0.682,0.42)
#  RGB{U8}(0.992,0.553,0.235)
#  RGB{U8}(0.945,0.412,0.075)
#  RGB{U8}(0.851,0.282,0.004)
#  RGB{U8}(0.651,0.212,0.012)
#  RGB{U8}(0.498,0.153,0.016)

# %%
plot([x -> cos(n*x) for n in 1:5], 0, 2, Scale.color_discrete_manual(orange[3:7]...))
# Out:
# Plot(...)

# %%
# Green

# %%
green = palette("Greens", 9)
# Out:
# 9-element Array{Any,1}:
#  RGB{U8}(0.969,0.988,0.961)
#  RGB{U8}(0.898,0.961,0.878)
#  RGB{U8}(0.78,0.914,0.753)
#  RGB{U8}(0.631,0.851,0.608)
#  RGB{U8}(0.455,0.769,0.463)
#  RGB{U8}(0.255,0.671,0.365)
#  RGB{U8}(0.137,0.545,0.271)
#  RGB{U8}(0.0,0.427,0.173)
#  RGB{U8}(0.0,0.267,0.106)

# %%
plot([x -> cos(n*x) for n in 1:5], 0, 2, Scale.color_discrete_manual(green[3:7]...))
# Out:
# Plot(...)

# %%
# Blue

# %%
blue = palette("Blues", 9)
# Out:
# 9-element Array{Any,1}:
#  RGB{U8}(0.969,0.984,1.0)
#  RGB{U8}(0.871,0.922,0.969)
#  RGB{U8}(0.776,0.859,0.937)
#  RGB{U8}(0.62,0.792,0.882)
#  RGB{U8}(0.42,0.682,0.839)
#  RGB{U8}(0.259,0.573,0.776)
#  RGB{U8}(0.129,0.443,0.71)
#  RGB{U8}(0.031,0.318,0.612)
#  RGB{U8}(0.031,0.188,0.42)

# %%
plot([x -> cos(n*x) for n in 1:5], 0, 2, Scale.color_discrete_manual(blue[3:7]...))
# Out:
# Plot(...)

# %%
# Purple

# %%
purple = palette("Purples", 9)
# Out:
# 9-element Array{Any,1}:
#  RGB{U8}(0.988,0.984,0.992)
#  RGB{U8}(0.937,0.929,0.961)
#  RGB{U8}(0.855,0.855,0.922)
#  RGB{U8}(0.737,0.741,0.863)
#  RGB{U8}(0.62,0.604,0.784)
#  RGB{U8}(0.502,0.49,0.729)
#  RGB{U8}(0.416,0.318,0.639)
#  RGB{U8}(0.329,0.153,0.561)
#  RGB{U8}(0.247,0.0,0.49)

# %%
plot([x -> cos(n*x) for n in 1:5], 0, 2, Scale.color_discrete_manual(purple[3:7]...))
# Out:
# Plot(...)
